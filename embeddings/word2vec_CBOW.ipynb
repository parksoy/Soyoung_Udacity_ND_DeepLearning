# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.0.0'

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
print(words[0])
# Out:
# anarchism

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  # data: 
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      # print("targets to avoid", targets_to_avoid)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
tf.nn.embedding_lookup?

# %%
# !python.__version__
# Out:
# /bin/sh: python.__version__: command not found

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  #loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,train_labels, num_sampled, vocabulary_size))

  loss = tf.reduce_mean(
     tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, 
                          labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))


  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
tf.nn.sampled_softmax_loss?

# %%
num_steps = 100001

loss_skip_gram = []

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_skip_gram.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-19-9a9a63171313>:6: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.165574
# Nearest to eight: wolfhound, fini, discordians, racetrack, stupa, ecusa, frantic, freight,
# Nearest to than: modulo, ashore, som, helpless, westview, capable, legacy, apa,
# Nearest to such: englewood, appreciating, now, penrose, skaters, emmanuel, devonian, uranus,
# Nearest to system: classless, gpmg, dancer, hejaz, strip, sars, hairdresser, interphase,
# Nearest to state: microvision, visits, subsumed, americium, emmer, wheelers, nitrate, maids,
# Nearest to an: wt, hateful, legged, embryo, routine, sm, appropriate, disruption,
# Nearest to all: annum, bavarians, donor, rijndael, fiduciary, investigation, wicca, piggy,
# Nearest to from: onstage, propagated, constants, historians, nymph, coercion, medell, diploid,
# Nearest to one: iwama, dopant, grundlagen, fuel, excelling, heimdall, memo, tents,
# Nearest to will: apply, bandy, cfo, kai, tainted, odi, respiratory, pardoned,
# Nearest to known: cuboctahedron, subunit, baines, teaser, hostels, corvus, ethologists, suffered,
# Nearest to so: progressions, coaches, repeaters, manchu, attainment, apocalypse, electrochemistry, dost,
# Nearest to as: discord, medina, pergamum, obscurity, boisbaudran, adjust, atlanta, helmholtz,
# Nearest to two: ayn, vocalizations, necessarily, osvaldo, oxidizer, oa, teleprinter, oxidise,
# Nearest to UNK: heron, stuff, cip, somali, serbian, gaius, myself, locator,
# Nearest to war: obedience, kpd, bowel, jen, microscopic, almohad, validation, gein,
# Average loss at step 2000: 4.367261
# Average loss at step 4000: 3.868291
# Average loss at step 6000: 3.781145
# Average loss at step 8000: 3.688203
# Average loss at step 10000: 3.616310
# Average loss at step 12000: 3.608706
# Average loss at step 14000: 3.576198
# Average loss at step 16000: 3.407760
# Average loss at step 18000: 3.455660
# Average loss at step 20000: 3.544728
# Average loss at step 22000: 3.501698
# Average loss at step 24000: 3.489787
# Average loss at step 26000: 3.479987
# Average loss at step 28000: 3.481374
# Average loss at step 30000: 3.502444
# Average loss at step 32000: 3.500516
# Average loss at step 34000: 3.497587
# Average loss at step 36000: 3.461312
# Average loss at step 38000: 3.303075
# Average loss at step 40000: 3.432225
# Average loss at step 42000: 3.433609
# Average loss at step 44000: 3.454884
# Average loss at step 46000: 3.456289
# Average loss at step 48000: 3.353526
# Average loss at step 50000: 3.385978
# Nearest to eight: six, nine, seven, four, five, three, two, one,
# Nearest to than: or, typeface, much, veneto, scheduled, crematorium, leaning, chaosium,
# Nearest to such: well, described, known, many, these, served, regarded, attic,
# Nearest to system: systems, gpmg, minarchists, retroviruses, belgian, monotone, process, actuarial,
# Nearest to state: react, territory, masovia, visits, government, ceylon, messina, nippur,
# Nearest to an: ium, neil, lamarck, breslau, corot, snobol, cowley, ombudsman,
# Nearest to all: these, any, some, dacian, valentinian, allegations, details, many,
# Nearest to from: into, in, through, tinge, after, egyptian, within, toward,
# Nearest to one: two, six, eight, four, three, seven, five, nine,
# Nearest to will: would, can, could, may, must, should, might, shall,
# Nearest to known: used, such, possible, regarded, described, recognized, defined, well,
# Nearest to so: electrochemistry, then, too, tremendous, coaches, if, debate, candidiasis,
# Nearest to as: twinning, by, became, when, prolific, salting, himalayan, is,
# Nearest to two: three, one, four, six, eight, seven, five, nine,
# Nearest to UNK: et, burton, harnack, gems, morphine, abscess, grinding, bayern,
# Nearest to war: validation, mayo, meson, torah, diffused, stiffer, exporters, jungian,
# Average loss at step 52000: 3.438261
# Average loss at step 54000: 3.428970
# Average loss at step 56000: 3.441121
# Average loss at step 58000: 3.396935
# Average loss at step 60000: 3.395087
# Average loss at step 62000: 3.236931
# Average loss at step 64000: 3.261611
# Average loss at step 66000: 3.405908
# Average loss at step 68000: 3.398800
# Average loss at step 70000: 3.359681
# Average loss at step 72000: 3.373696
# Average loss at step 74000: 3.351167
# Average loss at step 76000: 3.311756
# Average loss at step 78000: 3.348891
# Average loss at step 80000: 3.378342
# Average loss at step 82000: 3.407985
# Average loss at step 84000: 3.413837
# Average loss at step 86000: 3.393850
# Average loss at step 88000: 3.352253
# Average loss at step 90000: 3.367996
# Average loss at step 92000: 3.396966
# Average loss at step 94000: 3.256582
# Average loss at step 96000: 3.360702
# Average loss at step 98000: 3.242001
# Average loss at step 100000: 3.358882
# Nearest to eight: seven, nine, six, four, five, three, two, zero,
# Nearest to than: or, crematorium, scheduled, much, somewhat, indicating, regress, anglicisation,
# Nearest to such: well, known, these, follows, described, ephemeral, regarded, including,
# Nearest to system: systems, process, function, program, monistic, doors, geometry, purpose,
# Nearest to state: masovia, city, government, territory, nippur, officials, react, states,
# Nearest to an: specified, breslau, another, ium, alimony, neil, unveiled, mordor,
# Nearest to all: these, many, those, some, several, every, both, any,
# Nearest to from: into, in, toward, through, onto, during, tinge, egyptian,
# Nearest to one: two, four, seven, three, eight, five, six, nine,
# Nearest to will: would, must, can, could, may, should, might, cannot,
# Nearest to known: regarded, described, used, such, possible, referred, seen, defined,
# Nearest to so: too, thus, then, when, if, philips, rede, arbitration,
# Nearest to as: when, salting, gateways, offs, subhas, monotone, hungry, denunciations,
# Nearest to two: four, three, five, six, seven, one, eight, nine,
# Nearest to UNK: es, incapacitation, bayern, van, empty, noaa, locator, menu,
# Nearest to war: validation, mayo, meson, jungian, britain, wars, conceived, clerihew,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  context_window = 2 * skip_window
  assert batch_size % context_window == 0
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = context_window + 1
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span-1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # merge labels
  # subsample every `context_window` elements
  labels_merged = labels[::context_window]
  
  return batch, labels_merged

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
   
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print(batch)
    print(labels)
    
    #print('    batch:', [reverse_dictionary[bi] for bi in batch])
    #print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8/(2*skip_window))])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
# [5234   12    6 3081  195   12    2    6]
# [[3081]
#  [  12]
#  [   6]
#  [ 195]]
#
# with num_skips = 4 and skip_window = 2:
# [3081    6  195 5234  195    2   12 3081]
# [[12]
#  [ 6]]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
context_window = 2 * skip_window
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size / context_window, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)


  ##############
  # sum every `context_window` word embedding into one
  segment_ids = tf.constant([i for i in range(int(batch_size/context_window))]) #original i / context_window
  embed = tf.segment_sum(data=embed, segment_ids=segment_ids)
  ############### 
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  ##loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,train_labels, num_sampled, vocabulary_size))
    
  loss = tf.reduce_mean(
     tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, 
                          labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  
num_steps = 100001
loss_cbow = []

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    # _, l = tdb.debug([optimizer, loss], feed_dict=feed_dict, session=session)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_cbow.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py in merge_with(self, other)
#     580         for i, dim in enumerate(self._dims):
# --> 581           new_dims.append(dim.merge_with(other[i]))
#     582         return TensorShape(new_dims)
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py in merge_with(self, other)
#     134     other = as_dimension(other)
# --> 135     self.assert_is_compatible_with(other)
#     136     if self._value is None:
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#     107       raise ValueError("Dimensions %s and %s are not compatible"
# --> 108                        % (self, other))
#     109
#
# ValueError: Dimensions 64 and 128 are not compatible
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-354bc51c321e> in <module>()
#      45
#      46   # Optimizer.
# ---> 47   optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
#      48
#      49   # Compute the similarity between minibatch examples and all embeddings.
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     286         aggregation_method=aggregation_method,
#     287         colocate_gradients_with_ops=colocate_gradients_with_ops,
# --> 288         grad_loss=grad_loss)
#     289
#     290     vars_with_grad = [v for g, v in grads_and_vars if g is not None]
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     352         gate_gradients=(gate_gradients == Optimizer.GATE_OP),
#     353         aggregation_method=aggregation_method,
# --> 354         colocate_gradients_with_ops=colocate_gradients_with_ops)
#     355     if gate_gradients == Optimizer.GATE_GRAPH:
#     356       grads = control_flow_ops.tuple(grads)
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method)
#     498           if in_grad is not None:
#     499             if isinstance(in_grad, ops.Tensor):
# --> 500               in_grad.set_shape(t_in.get_shape())
#     501             _SetGrad(grads, t_in, in_grad)
#     502         if loop_state:
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shape(self, shape)
#     423         this tensor.
#     424     """
# --> 425     self._shape = self._shape.merge_with(shape)
#     426
#     427   @property
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py in merge_with(self, other)
#     583       except ValueError:
#     584         raise ValueError("Shapes %s and %s are not compatible" %
# --> 585                          (self, other))
#     586
#     587   def concatenate(self, other):
#
# ValueError: Shapes (64, 128) and (128, 128) are not compatible

# %% [markdown]
# # compare performance between skip-gram and CBOW

# %%
print(len(loss_cbow))
# Out:
# 0

# %%
# loss_cbow 
# loss_skip_gram
import matplotlib.pyplot as plt

steps = np.arange(len(loss_cbow))
fig, ax = plt.subplots()

ax.plot(steps, loss_skip_gram, 'b', label="skip gram")
ax.plot(steps, loss_cbow, 'g', label="cbow")

# Now add the legend with some customizations.
legend = ax.legend(loc='upper center', shadow=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-42f46f2bbe8e> in <module>()
#       6 fig, ax = plt.subplots()
#       7
# ----> 8 ax.plot(steps, loss_skip_gram, 'b', label="skip gram")
#       9 ax.plot(steps, loss_cbow, 'g', label="cbow")
#      10
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1525         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1526
# -> 1527         for line in self._get_lines(*args, **kwargs):
#    1528             self.add_line(line)
#    1529             lines.append(line)
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~/anaconda3/envs/embedding/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (0,) and (51,)
